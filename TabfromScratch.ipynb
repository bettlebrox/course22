# %%
from pathlib import Path
import zipfile,kaggle
path = Path('titanic')
kaggle.api.competition_download_cli(str(path))
zipfile.ZipFile(f'{path}.zip').extractall(path)
# Out:
# titanic.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from fastai.tabular.all import *

pd.options.display.float_format = '{:.2f}'.format
set_seed(42)

# %%
path.ls()
# Out:
# (#3) [Path('titanic/test.csv'),Path('titanic/train.csv'),Path('titanic/gender_submission.csv')]

# %%
df = pd.read_csv(path/'train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00      1
# 2                                 Heikkinen, Miss. Laina  female 26.00      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                               Allen, Mr. William Henry    male 35.00      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male 27.00      0
# 887                         Graham, Miss. Margaret Edith  female 19.00      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male 26.00      0
# 890                                  Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 0        0         A/5 21171  7.25   NaN        S
# 1        0          PC 17599 71.28   C85        C
# 2        0  STON/O2. 3101282  7.92   NaN        S
# 3        0            113803 53.10  C123        S
# 4        0            373450  8.05   NaN        S
# ..     ...               ...   ...   ...      ...
# 886      0            211536 13.00   NaN        S
# 887      0            112053 30.00   B42        S
# 888      2        W./C. 6607 23.45   NaN        S
# 889      0            111369 30.00  C148        C
# 890      0            370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['LogFare'] = np.log1p(df['Fare'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00      1
# 2                                 Heikkinen, Miss. Laina  female 26.00      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                               Allen, Mr. William Henry    male 35.00      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male 27.00      0
# 887                         Graham, Miss. Margaret Edith  female 19.00      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male 26.00      0
# 890                                  Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked  LogFare
# 0        0         A/5 21171  7.25   NaN        S     2.11
# 1        0          PC 17599 71.28   C85        C     4.28
# 2        0  STON/O2. 3101282  7.92   NaN        S     2.19
# 3        0            113803 53.10  C123        S     3.99
# 4        0            373450  8.05   NaN        S     2.20
# ..     ...               ...   ...   ...      ...      ...
# 886      0            211536 13.00   NaN        S     2.64
# 887      0            112053 30.00   B42        S     3.43
# 888      2        W./C. 6607 23.45   NaN        S     3.20
# 889      0            111369 30.00  C148        C     3.43
# 890      0            370376  7.75   NaN        Q     2.17
#
# [891 rows x 13 columns]

# %%
df.Cabin.str[0]
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Deck'] = df.Cabin.str[0].map(dict(A="ABC", B="ABC", C="ABC", D="DE", E="DE", F="FG", G="FG"))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00      1
# 2                                 Heikkinen, Miss. Laina  female 26.00      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                               Allen, Mr. William Henry    male 35.00      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male 27.00      0
# 887                         Graham, Miss. Margaret Edith  female 19.00      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male 26.00      0
# 890                                  Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked  LogFare Deck
# 0        0         A/5 21171  7.25   NaN        S     2.11  NaN
# 1        0          PC 17599 71.28   C85        C     4.28  ABC
# 2        0  STON/O2. 3101282  7.92   NaN        S     2.19  NaN
# 3        0            113803 53.10  C123        S     3.99  ABC
# 4        0            373450  8.05   NaN        S     2.20  NaN
# ..     ...               ...   ...   ...      ...      ...  ...
# 886      0            211536 13.00   NaN        S     2.64  NaN
# 887      0            112053 30.00   B42        S     3.43  ABC
# 888      2        W./C. 6607 23.45   NaN        S     3.20  NaN
# 889      0            111369 30.00  C148        C     3.43  ABC
# 890      0            370376  7.75   NaN        Q     2.17  NaN
#
# [891 rows x 14 columns]

# %%
df.loc[df['Deck'] == 'DE']
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 21            22         1       2
# 52            53         1       1
# 92            93         0       1
# 97            98         1       1
# ..           ...       ...     ...
# 835          836         1       1
# 853          854         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
#
#                                                     Name     Sex   Age  SibSp  \
# 6                                McCarthy, Mr. Timothy J    male 54.00      0
# 21                                 Beesley, Mr. Lawrence    male 34.00      0
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)  female 49.00      1
# 92                           Chaffee, Mr. Herbert Fuller    male 46.00      1
# 97                       Greenfield, Mr. William Bertram    male 23.00      0
# ..                                                   ...     ...   ...    ...
# 835                          Compton, Miss. Sara Rebecca  female 39.00      1
# 853                            Lines, Miss. Mary Conover  female 16.00      0
# 857                               Daly, Mr. Peter Denis     male 51.00      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Barron)  female 48.00      0
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female 47.00      1
#
#      Parch       Ticket  Fare    Cabin Embarked  LogFare Deck
# 6        0        17463 51.86      E46        S     3.97   DE
# 21       0       248698 13.00      D56        S     2.64   DE
# 52       0     PC 17572 76.73      D33        C     4.35   DE
# 92       0  W.E.P. 5734 61.17      E31        S     4.13   DE
# 97       1     PC 17759 63.36  D10 D12        C     4.16   DE
# ..     ...          ...   ...      ...      ...      ...  ...
# 835      1     PC 17756 83.16      E49        C     4.43   DE
# 853      1     PC 17592 39.40      D28        S     3.70   DE
# 857      0       113055 26.55      E17        S     3.32   DE
# 862      0        17466 25.93      D17        S     3.29   DE
# 871      1        11751 52.55      D35        S     3.98   DE
#
# [65 rows x 14 columns]

# %%
df.groupby('Ticket')['Ticket'].transform('count')
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    2
# 889    1
# 890    1
# Name: Ticket, Length: 891, dtype: int64

# %%
df.Name.str.split(', ', expand=True)[1].str.split('.', expand=True)[0]
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: 0, Length: 891, dtype: object

# %%
df = pd.read_csv(path/'train.csv')
def add_features(df):
    df['LogFare'] = np.log1p(df['Fare'])
    df['Deck'] = df.Cabin.str[0].map(dict(A="ABC", B="ABC", C="ABC", D="DE", E="DE", F="FG", G="FG"))
    df['Family'] = df.SibSp+df.Parch
    df['Alone'] = df.Family==1
    df['TicketFreq'] = df.groupby('Ticket')['Ticket'].transform('count')
    df['Title'] = df.Name.str.split(', ', expand=True)[1].str.split('.', expand=True)[0]
    df['Title'] = df.Title.map(dict(Mr="Mr",Miss="Miss",Mrs="Mrs",Master="Master")).value_counts(dropna=False)

add_features(df)

# %%
df.shape
# Out:
# (891, 18)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00      1
# 2                                 Heikkinen, Miss. Laina  female 26.00      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                               Allen, Mr. William Henry    male 35.00      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male 27.00      0
# 887                         Graham, Miss. Margaret Edith  female 19.00      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male 26.00      0
# 890                                  Dooley, Mr. Patrick    male 32.00      0
#
#      Parch            Ticket  Fare Cabin Embarked  LogFare Deck  Family  \
# 0        0         A/5 21171  7.25   NaN        S     2.11  NaN       1
# 1        0          PC 17599 71.28   C85        C     4.28  ABC       1
# 2        0  STON/O2. 3101282  7.92   NaN        S     2.19  NaN       0
# 3        0            113803 53.10  C123        S     3.99  ABC       1
# 4        0            373450  8.05   NaN        S     2.20  NaN       0
# ..     ...               ...   ...   ...      ...      ...  ...     ...
# 886      0            211536 13.00   NaN        S     2.64  NaN       0
# 887      0            112053 30.00   B42        S     3.43  ABC       0
# 888      2        W./C. 6607 23.45   NaN        S     3.20  NaN       3
# 889      0            111369 30.00  C148        C     3.43  ABC       0
# 890      0            370376  7.75   NaN        Q     2.17  NaN       0
#
#      Alone  TicketFreq Title
# 0     True           1    Mr
# 1     True           1   Mrs
# 2    False           1  Miss
# 3     True           2   Mrs
# 4    False           1    Mr
# ..     ...         ...   ...
# 886  False           1   Rev
# 887  False           1  Miss
# 888  False           2  Miss
# 889  False           1    Mr
# 890  False           1    Mr
#
# [891 rows x 18 columns]

# %%
df.sample()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  LogFare      891 non-null    float64
#  13  Deck         203 non-null    object
#  14  Family       891 non-null    int64
#  15  Alone        891 non-null    bool
#  16  TicketFreq   891 non-null    int64
#  17  Title        891 non-null    object
# dtypes: bool(1), float64(3), int64(7), object(7)
# memory usage: 119.3+ KB
